# %%
import pandas as pd
df=pd.read_csv("Dataset .csv")
df.columns
delivery_count= df['Has Online delivery'].value_counts()
print(delivery_count)
total_restaurants=len(df)
for delivery,count in delivery_count.items():
  percentage=(count/total_restaurants)*100
  print(f"{delivery}:{percentage:.2f}%")
avg_rating_delivery=df.groupby('Has Online delivery')['Aggregate rating'].mean()
print(avg_rating_delivery)
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64
# No:74.34%
# Yes:25.66%
# Has Online delivery
# No     2.465296
# Yes    3.248837
# Name: Aggregate rating, dtype: float64
